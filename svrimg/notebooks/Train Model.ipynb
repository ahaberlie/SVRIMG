# %% [markdown]
# # Training an CNN to automatically classify storm morphology
#
# ### Preprocessing
#
# 1) Set the number of classes and size of the image (including the '3rd' dimension, even though these are greyscale)
#
# 2) Read in the files using the get_example_data utility
#
# 3) Normalize the data by 80 dBZ
#
# 4) Verify the shape of the training, validation, and testing datasets
#
# 5) Transform the "single number" classifications into keras friendly arrays.

# %%
#Based on examples from the Keras documentation
import sys
sys.path.insert(0, '..')
import numpy as np
from tensorflow import keras
from tensorflow.keras import layers
import pickle
from utils.get_images import get_example_data

num_classes = 6
input_shape = (136, 136, 1)

(x_train, y_train) = get_example_data('training', data_dir="../data/pkls/")
(x_val, y_val) = get_example_data('validation', data_dir="../data/pkls/")
(x_test, y_test) = get_example_data('testing', data_dir="../data/pkls/")

#Normalize by 80 dBZ
x_train = x_train.astype("float32") / 80
x_test = x_test.astype("float32") / 80
x_val = x_val.astype("float32") / 80

print("x_train shape:", x_train.shape)
print(x_train.shape[0], "train samples")
print(x_val.shape[0], "validate samples")
print(x_test.shape[0], "test samples")

y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)
# Out:
# x_train shape: (1331, 136, 136, 1)
# 1331 train samples
# 110 validate samples
# 300 test samples

# %% [markdown]
# ### Create a simple 3 convolutional and 1 dense layer CNN

# %%
model = keras.Sequential(
    [
        keras.Input(shape=(136, 136, 1)),
        layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
        layers.SpatialDropout2D(0.3),
        layers.MaxPooling2D(pool_size=(3, 3)),
        layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
        layers.SpatialDropout2D(0.3),
        layers.MaxPooling2D(pool_size=(3, 3)),
        layers.Conv2D(128, kernel_size=(3, 3), activation="relu"),
        layers.SpatialDropout2D(0.3),
        layers.MaxPooling2D(pool_size=(3, 3)),
        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dropout(0.6),
        layers.Dense(num_classes, activation="softmax"),
    ]
)

keras.utils.plot_model(model, show_shapes=True)
# Out:
# WARNING:tensorflow:From C:\Users\ahaberlie1\Anaconda3\envs\tensorflow\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:Large dropout rate: 0.6 (>0.5). In TensorFlow 2.x, dropout() uses dropout rate instead of keep_prob. Please ensure that this is intended.

# %% [markdown]
# ### Use Data Augmentation to reduce overfitting
#
# We can show how this works with one example.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = 8, 8

from utils.map_helper import radar_colormap, draw_box_plot
from matplotlib.colors import BoundaryNorm

cmap = radar_colormap()
classes = np.array(list(range(0, 85, 5)))
norm = BoundaryNorm(classes, ncolors=cmap.N)

sample = x_test[52]
ax = plt.subplot(1,1,1)
draw_box_plot(ax, sample.squeeze()*80)
# Out:
# <AxesSubplot:xlabel='km', ylabel='km'>

# %% [markdown]
# We should try to avoid shifting the image left and right, because the location of the
# storm report is right in the middle of each image.  Instead, rotate the image and zoom in and out slightly.
# It is also important to ask yourself, does the image augmentation make sense?
#
# We can visualize this with 9 randomly generated examples.

# %%
from keras.preprocessing.image import ImageDataGenerator
from numpy import expand_dims

plt.rcParams['figure.figsize'] = 20, 20

samples = expand_dims(sample, 0)

datagen = ImageDataGenerator(rotation_range=55, zoom_range=[0.9,1.0], fill_mode="reflect")

aug_imgs = datagen.flow(samples, batch_size=1)

for i in range(9):
   
    ax = plt.subplot(3,3,i+1)

    batch = aug_imgs.next()

    draw_box_plot(ax, batch[0].squeeze()*80)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Create an image generator for the training data and validation data and pass these values into model.fit().  Wait for the model to finish 100 epochs and test how it did!
#
# Note: modify the "workers" argument depending on what kind of CPU you have.  This was tested on a 20 core machine.

# %%
batch_size = 128
epochs = 100

traingen = ImageDataGenerator(rotation_range=55, zoom_range=[0.9,1.0], fill_mode="reflect")
valgen = ImageDataGenerator(rotation_range=55, zoom_range=[0.9,1.0], fill_mode="reflect")

datagen.fit(x_train)
valgen.fit(x_val)

model.compile(loss="categorical_crossentropy", optimizer="adam", metrics=["accuracy"])

history = model.fit(datagen.flow(x_train, y_train, batch_size=32), 
                    epochs=epochs, steps_per_epoch=len(x_train) / 32, 
                    validation_data=valgen.flow(x_val, y_val, batch_size=32), workers=8)
# Out:
# Epoch 1/100
# 40/41 [===========================>..] - ETA: 0s - loss: 1.3107 - acc: 0.4594Epoch 1/100
# 42/41 [==============================] - 4s 96ms/step - loss: 1.3009 - acc: 0.4688 - val_loss: 0.9079 - val_acc: 0.6455
# Epoch 2/100
# 39/41 [===========================>..] - ETA: 0s - loss: 1.0232 - acc: 0.6300Epoch 1/100
# 42/41 [==============================] - 1s 23ms/step - loss: 1.0258 - acc: 0.6281 - val_loss: 0.7887 - val_acc: 0.7273
# Epoch 3/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.9475 - acc: 0.6664Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.9498 - acc: 0.6657 - val_loss: 0.8460 - val_acc: 0.7273
# Epoch 4/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.8730 - acc: 0.6914Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.8787 - acc: 0.6912 - val_loss: 0.8267 - val_acc: 0.7000
# Epoch 5/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.8253 - acc: 0.7143Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.8123 - acc: 0.7220 - val_loss: 0.7022 - val_acc: 0.7818
# Epoch 6/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.7701 - acc: 0.7563Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.7707 - acc: 0.7536 - val_loss: 0.6696 - val_acc: 0.7909
# Epoch 7/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.7521 - acc: 0.7498Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.7450 - acc: 0.7551 - val_loss: 0.7060 - val_acc: 0.7909
# Epoch 8/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.7436 - acc: 0.7781Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.7487 - acc: 0.7724 - val_loss: 0.6931 - val_acc: 0.8000
# Epoch 9/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.6729 - acc: 0.7916Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.6761 - acc: 0.7881 - val_loss: 0.5911 - val_acc: 0.8000
# Epoch 10/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.6408 - acc: 0.7768Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.6499 - acc: 0.7754 - val_loss: 0.6005 - val_acc: 0.8545
# Epoch 11/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.6837 - acc: 0.8000Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.6697 - acc: 0.8062 - val_loss: 0.6203 - val_acc: 0.8273
# Epoch 12/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.6415 - acc: 0.7948Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.6363 - acc: 0.7956 - val_loss: 0.5646 - val_acc: 0.8364
# Epoch 13/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.6410 - acc: 0.8074Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.6373 - acc: 0.8099 - val_loss: 0.6035 - val_acc: 0.7727
# Epoch 14/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.6100 - acc: 0.8202Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.6020 - acc: 0.8219 - val_loss: 0.5575 - val_acc: 0.8273
# Epoch 15/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.5823 - acc: 0.8211Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5723 - acc: 0.8227 - val_loss: 0.5309 - val_acc: 0.8182
# Epoch 16/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.5947 - acc: 0.8097Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5811 - acc: 0.8152 - val_loss: 0.5173 - val_acc: 0.8636
# Epoch 17/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.5546 - acc: 0.8345Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5515 - acc: 0.8347 - val_loss: 0.5902 - val_acc: 0.8636
# Epoch 18/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.5698 - acc: 0.8345- ETA: 0s - loss: 0.5677 - acc: 0.8Epoch 1/100
# 42/41 [==============================] - 1s 21ms/step - loss: 0.5741 - acc: 0.8317 - val_loss: 0.4799 - val_acc: 0.8545
# Epoch 19/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.5487 - acc: 0.8268Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5458 - acc: 0.8287 - val_loss: 0.5241 - val_acc: 0.8727
# Epoch 20/100
# 38/41 [==========================>...] - ETA: 0s - loss: 0.5529 - acc: 0.8371Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5494 - acc: 0.8392 - val_loss: 0.5779 - val_acc: 0.8455
# Epoch 21/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.5309 - acc: 0.8508Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5263 - acc: 0.8497 - val_loss: 0.4586 - val_acc: 0.8545
# Epoch 22/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.5198 - acc: 0.8340Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5163 - acc: 0.8362 - val_loss: 0.4589 - val_acc: 0.8273
# Epoch 23/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4998 - acc: 0.8516Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4979 - acc: 0.8512 - val_loss: 0.5134 - val_acc: 0.8727
# Epoch 24/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.5035 - acc: 0.8335Epoch 1/100
# 42/41 [==============================] - 1s 21ms/step - loss: 0.5090 - acc: 0.8310 - val_loss: 0.4663 - val_acc: 0.8545
# Epoch 25/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.5040 - acc: 0.8398Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.5050 - acc: 0.8385 - val_loss: 0.4423 - val_acc: 0.8636
# Epoch 26/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.4988 - acc: 0.8421Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5066 - acc: 0.8445 - val_loss: 0.4934 - val_acc: 0.8455
# Epoch 27/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.5019 - acc: 0.8508Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.5027 - acc: 0.8505 - val_loss: 0.4259 - val_acc: 0.8818
# Epoch 28/100
# 38/41 [==========================>...] - ETA: 0s - loss: 0.4649 - acc: 0.8620Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4754 - acc: 0.8603 - val_loss: 0.4025 - val_acc: 0.8909
# Epoch 29/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4916 - acc: 0.8516Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4935 - acc: 0.8527 - val_loss: 0.3588 - val_acc: 0.8818
# Epoch 30/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.4628 - acc: 0.8558Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4671 - acc: 0.8550 - val_loss: 0.4423 - val_acc: 0.8273
# Epoch 31/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.4724 - acc: 0.8637Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4732 - acc: 0.8625 - val_loss: 0.3471 - val_acc: 0.8636
# Epoch 32/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4460 - acc: 0.8664Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4535 - acc: 0.8640 - val_loss: 0.3485 - val_acc: 0.8727
# Epoch 33/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4550 - acc: 0.8642Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4553 - acc: 0.8640 - val_loss: 0.3724 - val_acc: 0.8727
# Epoch 34/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4522 - acc: 0.8753Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.4449 - acc: 0.8760 - val_loss: 0.3704 - val_acc: 0.8727
# Epoch 35/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4587 - acc: 0.8698Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4634 - acc: 0.8685 - val_loss: 0.3878 - val_acc: 0.8818
# Epoch 36/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4304 - acc: 0.8745Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4271 - acc: 0.8753 - val_loss: 0.3370 - val_acc: 0.8909
# Epoch 37/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.4210 - acc: 0.8713Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4171 - acc: 0.8715 - val_loss: 0.4024 - val_acc: 0.8636
# Epoch 38/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4152 - acc: 0.8769Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4170 - acc: 0.8775 - val_loss: 0.3359 - val_acc: 0.8909
# Epoch 39/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3908 - acc: 0.8876Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.4008 - acc: 0.8850 - val_loss: 0.3838 - val_acc: 0.8636
# Epoch 40/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.4107 - acc: 0.8838Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.4096 - acc: 0.8843 - val_loss: 0.3022 - val_acc: 0.9091
# Epoch 41/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3955 - acc: 0.8761Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.4006 - acc: 0.8715 - val_loss: 0.3313 - val_acc: 0.8909
# Epoch 42/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3944 - acc: 0.8800Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.3882 - acc: 0.8813 - val_loss: 0.3188 - val_acc: 0.8818
# Epoch 43/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.4133 - acc: 0.8721Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4169 - acc: 0.8730 - val_loss: 0.3706 - val_acc: 0.8636
# Epoch 44/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3709 - acc: 0.8887Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3719 - acc: 0.8888 - val_loss: 0.3632 - val_acc: 0.8545
# Epoch 45/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.4439 - acc: 0.8656Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4421 - acc: 0.8655 - val_loss: 0.3673 - val_acc: 0.8545
# Epoch 46/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3794 - acc: 0.8856Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3832 - acc: 0.8835 - val_loss: 0.3738 - val_acc: 0.8818
# Epoch 47/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.4052 - acc: 0.8794Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.4048 - acc: 0.8813 - val_loss: 0.3119 - val_acc: 0.9000
# Epoch 48/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3962 - acc: 0.8753Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3997 - acc: 0.8730 - val_loss: 0.2800 - val_acc: 0.8909
# Epoch 49/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3918 - acc: 0.8871Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3940 - acc: 0.8843 - val_loss: 0.3818 - val_acc: 0.8545
# Epoch 50/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3564 - acc: 0.8927Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3575 - acc: 0.8926 - val_loss: 0.3398 - val_acc: 0.8727
# Epoch 51/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3874 - acc: 0.8853Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3952 - acc: 0.8858 - val_loss: 0.2987 - val_acc: 0.9000
# Epoch 52/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3862 - acc: 0.8898Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3834 - acc: 0.8888 - val_loss: 0.2845 - val_acc: 0.9091
# Epoch 53/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3700 - acc: 0.8958Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3732 - acc: 0.8941 - val_loss: 0.2762 - val_acc: 0.9091
# Epoch 54/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3676 - acc: 0.8871Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3608 - acc: 0.8873 - val_loss: 0.3116 - val_acc: 0.8727
# Epoch 55/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3617 - acc: 0.8850Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.3605 - acc: 0.8850 - val_loss: 0.3059 - val_acc: 0.8727
# Epoch 56/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3455 - acc: 0.8895Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3480 - acc: 0.8903 - val_loss: 0.2776 - val_acc: 0.8727
# Epoch 57/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3684 - acc: 0.8999Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3681 - acc: 0.8986 - val_loss: 0.2577 - val_acc: 0.8909
# Epoch 58/100
# 38/41 [==========================>...] - ETA: 0s - loss: 0.3331 - acc: 0.8994Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3392 - acc: 0.8978 - val_loss: 0.3776 - val_acc: 0.8727
# Epoch 59/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3698 - acc: 0.8919Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3690 - acc: 0.8926 - val_loss: 0.2799 - val_acc: 0.8909
# Epoch 60/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3454 - acc: 0.8988Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.3499 - acc: 0.8978 - val_loss: 0.2697 - val_acc: 0.9000
# Epoch 61/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3163 - acc: 0.9015Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3127 - acc: 0.9031 - val_loss: 0.2617 - val_acc: 0.9091
# Epoch 62/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3243 - acc: 0.9134Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3269 - acc: 0.9121 - val_loss: 0.3145 - val_acc: 0.8909
# Epoch 63/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3384 - acc: 0.9084Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3419 - acc: 0.9068 - val_loss: 0.2902 - val_acc: 0.8727
# Epoch 64/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3425 - acc: 0.8903Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3427 - acc: 0.8918 - val_loss: 0.2963 - val_acc: 0.8818
# Epoch 65/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3151 - acc: 0.8984Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3092 - acc: 0.9008 - val_loss: 0.2802 - val_acc: 0.8818
# Epoch 66/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3312 - acc: 0.8907Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3429 - acc: 0.8896 - val_loss: 0.2823 - val_acc: 0.9000
# Epoch 67/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3470 - acc: 0.8938Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.3408 - acc: 0.8956 - val_loss: 0.2582 - val_acc: 0.8818
# Epoch 68/100
# 38/41 [==========================>...] - ETA: 0s - loss: 0.3010 - acc: 0.9160Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3187 - acc: 0.9098 - val_loss: 0.3157 - val_acc: 0.9000
# Epoch 69/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3239 - acc: 0.9030Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3257 - acc: 0.9016 - val_loss: 0.2794 - val_acc: 0.8909
# Epoch 70/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3263 - acc: 0.8996Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3247 - acc: 0.9001 - val_loss: 0.2264 - val_acc: 0.9182
# Epoch 71/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3307 - acc: 0.9022Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3343 - acc: 0.9001 - val_loss: 0.2330 - val_acc: 0.9364
# Epoch 72/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3232 - acc: 0.8982Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3223 - acc: 0.8978 - val_loss: 0.2867 - val_acc: 0.8909
# Epoch 73/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3124 - acc: 0.9092Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3150 - acc: 0.9091 - val_loss: 0.2789 - val_acc: 0.8909
# Epoch 74/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.3194 - acc: 0.9069Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3127 - acc: 0.9091 - val_loss: 0.3657 - val_acc: 0.8727
# Epoch 75/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2922 - acc: 0.9092Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2892 - acc: 0.9091 - val_loss: 0.2594 - val_acc: 0.8909
# Epoch 76/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3107 - acc: 0.9021Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3071 - acc: 0.9031 - val_loss: 0.3124 - val_acc: 0.8909
# Epoch 77/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3021 - acc: 0.9108Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2984 - acc: 0.9121 - val_loss: 0.4018 - val_acc: 0.8727
# Epoch 78/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2972 - acc: 0.9061Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2937 - acc: 0.9091 - val_loss: 0.3447 - val_acc: 0.8818
# Epoch 79/100
# 38/41 [==========================>...] - ETA: 0s - loss: 0.2729 - acc: 0.9127Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2676 - acc: 0.9144 - val_loss: 0.2762 - val_acc: 0.9091
# Epoch 80/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2942 - acc: 0.9013Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2867 - acc: 0.9031 - val_loss: 0.2939 - val_acc: 0.8909
# Epoch 81/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.2931 - acc: 0.9092Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2949 - acc: 0.9076 - val_loss: 0.2701 - val_acc: 0.8909
# Epoch 82/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2718 - acc: 0.9148Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.2741 - acc: 0.9144 - val_loss: 0.2727 - val_acc: 0.8909
# Epoch 83/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3115 - acc: 0.9021Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3155 - acc: 0.8993 - val_loss: 0.2957 - val_acc: 0.8727
# Epoch 84/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2793 - acc: 0.9166Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2800 - acc: 0.9159 - val_loss: 0.2484 - val_acc: 0.8909
# Epoch 85/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.2713 - acc: 0.9115Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2720 - acc: 0.9113 - val_loss: 0.3079 - val_acc: 0.8636
# Epoch 86/100
# 38/41 [==========================>...] - ETA: 0s - loss: 0.2604 - acc: 0.9119Epoch 1/100
# 42/41 [==============================] - 1s 21ms/step - loss: 0.2652 - acc: 0.9098 - val_loss: 0.2867 - val_acc: 0.9000
# Epoch 87/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.3035 - acc: 0.9029Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.3012 - acc: 0.9023 - val_loss: 0.2853 - val_acc: 0.9091
# Epoch 88/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2674 - acc: 0.9187Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2835 - acc: 0.9166 - val_loss: 0.3035 - val_acc: 0.8727
# Epoch 89/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2568 - acc: 0.9258- ETA: 0s - loss: 0.2654 - acc: 0Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2659 - acc: 0.9234 - val_loss: 0.2979 - val_acc: 0.8818
# Epoch 90/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.2780 - acc: 0.9130Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2764 - acc: 0.9136 - val_loss: 0.2923 - val_acc: 0.8909
# Epoch 91/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2763 - acc: 0.9195Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.2813 - acc: 0.9181 - val_loss: 0.2358 - val_acc: 0.9000
# Epoch 92/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2833 - acc: 0.9124Epoch 1/100
# 42/41 [==============================] - 1s 24ms/step - loss: 0.2953 - acc: 0.9083 - val_loss: 0.2293 - val_acc: 0.9182
# Epoch 93/100
# 41/41 [============================>.] - ETA: 0s - loss: 0.3135 - acc: 0.9069Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.3128 - acc: 0.9068 - val_loss: 0.2856 - val_acc: 0.8727
# Epoch 94/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2745 - acc: 0.9183Epoch 1/100
# 42/41 [==============================] - 1s 25ms/step - loss: 0.2758 - acc: 0.9159 - val_loss: 0.2522 - val_acc: 0.8909
# Epoch 95/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2524 - acc: 0.9179Epoch 1/100
# 42/41 [==============================] - 1s 23ms/step - loss: 0.2531 - acc: 0.9159 - val_loss: 0.2412 - val_acc: 0.9000
# Epoch 96/100
# 40/41 [===========================>..] - ETA: 0s - loss: 0.2756 - acc: 0.9155Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2679 - acc: 0.9174 - val_loss: 0.2998 - val_acc: 0.9182
# Epoch 97/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2492 - acc: 0.9198Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2512 - acc: 0.9196 - val_loss: 0.2501 - val_acc: 0.9000
# Epoch 98/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2528 - acc: 0.9198Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2582 - acc: 0.9189 - val_loss: 0.2863 - val_acc: 0.9000
# Epoch 99/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2965 - acc: 0.9077Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2996 - acc: 0.9083 - val_loss: 0.2757 - val_acc: 0.8909
# Epoch 100/100
# 39/41 [===========================>..] - ETA: 0s - loss: 0.2594 - acc: 0.9117Epoch 1/100
# 42/41 [==============================] - 1s 22ms/step - loss: 0.2619 - acc: 0.9121 - val_loss: 0.2716 - val_acc: 0.8909

# %% [markdown]
# # Check the change in training and validation accuracy over epochs.
#
# Divergence of these two generally suggests overfitting.  This can be addressed by image augmentation,
# dropout, and getting more data.

# %%
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = 10, 6

plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val.'], loc='upper left')
plt.show()

# %% [markdown]
# ### Check the testing accuracy
#
# If it is similar to the validation accuracy, the model is probably learning something.

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print("Test loss:", score[0])
print("Test accuracy:", score[1])
# Out:
# Test loss: 0.6389258912205696
# Test accuracy: 0.87666667

# %% [markdown]
# ### Apply the model to the testing images and compare the predictions to the actual labels

# %%
from utils.get_tables import get_svrgis_table, get_pred_tables

actual = get_pred_tables(data_dir="../data/csvs/", example=True, remove_first_row=True)

svrgis = get_svrgis_table(data_dir="../data/csvs/")

actual = actual.join(svrgis)

actual.head()
# Out:
#                         Class Code Class Name   om  tz  st  stf  stn  mag  \
# UNID
# 199604200208z000000206           0   Cellular  206   3  IL   17   38    0
# 199604192244z000000197           0   Cellular  197   3  IL   17    8    0
# 199605280130z000000300           0   Cellular  300   3  IL   17   49    0
# 199605280140z000000298           0   Cellular  298   3  IL   17   50    0
# 199604192307z000000207           0   Cellular  207   3  IL   17   11    2
#
#                         inj  fat  ...  f3  f4  fc            init_date  \
# UNID                              ...
# 199604200208z000000206    0    0  ...   0   0   0  1996-04-19-20:08:00
# 199604192244z000000197    0    0  ...   0   0   0  1996-04-19-16:44:00
# 199605280130z000000300    0    0  ...   0   0   0  1996-05-27-19:30:00
# 199605280140z000000298    0    0  ...   0   0   0  1996-05-27-19:40:00
# 199604192307z000000207    1    0  ...   0   0   0  1996-04-19-17:07:00
#
#                                fmt_date         date_utc    yr  mo  dy  hr
# UNID
# 199604200208z000000206  4/19/1996 20:08   4/20/1996 2:08  1996   4  20   2
# 199604192244z000000197  4/19/1996 16:44  4/19/1996 22:44  1996   4  19  22
# 199605280130z000000300  5/27/1996 19:30   5/28/1996 1:30  1996   5  28   1
# 199605280140z000000298  5/27/1996 19:40   5/28/1996 1:40  1996   5  28   1
# 199604192307z000000207  4/19/1996 17:07  4/19/1996 23:07  1996   4  19  23
#
# [5 rows x 33 columns]

# %%
from utils.get_images import get_img_list

plt.rcParams['figure.figsize'] = 25, 25
plt.rcParams['xtick.labelsize'] = 20
plt.rcParams['ytick.labelsize'] = 20
plt.rcParams['axes.labelsize'] = 20

#Testing data are 2014 and on.  It is "cheating" to look at earlier data.
sample = actual[actual.yr>=2014].sample(9)

#Load the images and transform them to be "CNN-friendly"
imgs = get_img_list(sample.index.values, "../data/tor/")
imgs = expand_dims(imgs, 3)
imgs = imgs / 80 #normalize

#Identify the column with the highest probability
pred = np.argmax(model.predict(imgs), axis=1)
truth = sample['Class Code'].values

lookup = {0:'Cellular', 1:'QLCS', 2:'Tropical', 3:'Other', 4:'Noise', 5:'Missing'}

for i, (img, p) in enumerate(zip(imgs, pred)):
    
    ax = plt.subplot(3, 3, i+1)
    
    ax = draw_box_plot(ax, img*80, cbar_shrink=0.8)
    
    ax.set_title("Prediction: {}\nActual: {}".format(lookup[p], lookup[truth[i]]), fontsize=25)
